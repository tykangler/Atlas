# %% [markdown]
# # Text Processing and Pipelines with Spacy

# %% [markdown]
# ## NLP Dependency Labels
#
# ### Subjects
#
# |                           |                                                                                                                 |
# |---------------------------|-----------------------------------------------------------------------------------------------------------------|
# | Nominal Subject           | A nominal subject (`nsubj`) is a non-clausal constituent in the subject position of an active verb.             |
# | Nominal subject (passive) | A nominal passive subject (`nsubjpass`) is a non-clausal constituent in the subject position of a passive verb. |
# | Clausal subject           | A clausal subject (`csubj`) is a clause in the subject position of an active verb.                              |
# | Clausal subject (passive) | A clausal passive subject (`csubjpass`) is a clause in the subject position of a passive verb.                  |
# | Agent                     | An agent (`agent`) is the complement of a passive verb that is the surface subject of its active form.          |
# | Expletive                 | An expletive (`expl`) is an existential there in the subject position.                                          |
#
# ### Objects
#
# |                  |                                                                                                                      |
# |------------------|----------------------------------------------------------------------------------------------------------------------|
# | Direct object    | A direct object (`dobj`) is a noun phrase that is the accusative object of a (di)transitive verb.                    |
# | Dative           | A dative (`dative`) is a nominal or prepositional object of dative-shifting verb.                                    |
# | Attribute        | An attribute (`attr`) is a noun phrase that is a non-VP predicate usually following a copula verb.                   |
# | Object predicate | An object predicate (`oprd`) is a non-VP predicate in a small clause that functions like the predicate of an object. |
#
#
# ### Complements
#
# |                         |                                                                                                                                                  |
# |-------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------|
# | Clausal complement      | A clausal complement (`ccomp`) is a clause with an internal subject that modifies the head of an `ADJP\|ADVP\|NML\|NP\|WHNP\|VP\|SINV\|SQ`\.  |
# | Open clausal complement | An open clausal complement (`xcomp`) is a clause without an internal subject that modifies the head of an `ADJP\|ADVP\|VP\|SINV\|SQ`\.        |
# | Adjectival complement   | An adjectival complement (`acomp`) is an adjective phrase that modifies the head of a `VP\|SINV\|SQ`, that is usually a verb\.                |
#
# ### Nominals
#
# |                           |                                                                                                                                                                                                                                                                                                                                                            |
# |---------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Appositional modifier     | An appositional modifier (`appos`) of an `NML\|NP` is a noun phrase immediately preceded by another noun phrase, which gives additional information to its preceding noun phrase.                                                                                                                                                                      |
# | Clausal modifier          | A finite or non-finite clausal modifier (`acl`) is either an infinitival modifier is an infinitive clause or phrase that modifies the head of a noun phrase, or a participial modifier is a clause or phrase whose head is a verb in a participial form (e.g., gerund, past participle) that modifies the head of a noun phrase, or a complement. |
# | Releative clause modifier | A relative clause modifier (`relcl`) is a either relative clause or a reduced relative clause that modifies the head of an `NML\|NP\|WHNP`\.                                                                                                                                                                                                            |
# | Determiner                | A determiner (`det`) is a word token whose pos tag is `DT\|WDT\|WP` that modifies the head of a noun phrase\.                                                                                                                                                                                                                                           |
# | Pre-determiner           | A predeterminer (`predet`) is a word token whose pos tag is PDT that modifies the head of a noun phrase\.                                                                                                                                                                                                                                               |
# | Numeric modifier          | A numeric modifier (`nummod`) is any number or quantifier phrase that modifies the head of a noun phrase\.                                                                                                                                                                                                                                              |
# | Adjectival modifier       | An adjectival modifier (`amod`) is an adjective or an adjective phrase that modifies the meaning of another word, usually a noun\.                                                                                                                                                                                                                      |
# | Possession modifier       | A possession modifier (`poss`) is either a possessive determiner (PRP$) or a `NML\|NP\|WHNP` containing a possessive ending that modifies the head of a `ADJP\|NML\|NP\|QP\|WHNP`\.                                                                                                                                                                   |
# | Modifier of nominal       | A modifier of nominal (`nmod`) is any unclassified dependent that modifies the head of a noun phrase\.                                                                                                                                                                                                                                                  |
#
#
# ### Adverbials
#
# |                           |                                                                                                              |
# |---------------------------|--------------------------------------------------------------------------------------------------------------|
# | Adverbial modifier        | An adverbial modifier (`advmod`) is an adverb or an adverb phrase that modifies the meaning of another word. |
# | Adverbial clause modifier | An adverbial clause modifier (`advcl`) is a clause that acts like an adverbial modifier.                     |
#
#
# ### Negation modifier
#
# A negation modifier (`neg`) is an adverb that gives negative meaning to its head.
#
# ### Noun phrase as adverbial modifier
#
# An adverbial noun phrase modifier (`npmod`) is a noun phrase that acts like an adverbial modifier.
#
# ### Prepositions
#
# |                             |                                                                                                                                                                                              |
# |-----------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Object of a preposition     | An object of a preposition (`pobj`) is a noun phrase that modifies the head of a prepositional phrase, which is usually a preposition but can be a verb in a participial form such as `VBG`. |
# | Complement of a preposition | A complement of a preposition (`pcomp`) is any dependent that is not a `pobj` but modifies the head of a prepositional phrase.                                                               |
#
#
# ### Coordination
#
# |                             |                                                                                                                                                          |
# |-----------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Conjunct                    | A conjunct (`conj`) is a dependent of the leftmost conjunct in coordination.                                                                             |
# | Coordinating conjunction    | A coordinating conjunction (`cc`) is a dependent of the leftmost conjunct in coordination.                                                               |
# | Pre-correlative conjunction | A pre-correlative conjunction (`preconj`) is the first part of a correlative conjunction that becomes a dependent of the first conjunct in coordination. |
# | Prepositional modifier      | A prepositional modifier (`prep`) is any prepositional phrase that modifies the meaning of its head.                                                     |
#
#
# ### Auxiliaries
#
# |                     |                                                                                                                              |
# |---------------------|------------------------------------------------------------------------------------------------------------------------------|
# | Auxiliary           | An auxiliary (`aux`) is an auxiliary or modal verb that gives further information about the main verb (e.g., tense, aspect). |
# | Auxiliary (passive) | A passive auxiliary (`auxpass`) is an auxiliary verb, be, become, or get, that modifies a passive verb.                      |
#
#
# ### Compund words
#
# |             |                                                                                                                                                                                                                                    |
# |-------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Compound    | A compound (`compound`) is either a noun modifying the head of noun phrase, a number modifying the head of quantifier phrase, or a hyphenated word (or a preposition modifying the head of the prepositioanl phrase).              |
# | Particle    | A particle (`prt`) is a preposition in a phrasal verb that forms a verb-particle construction.                                                                                                                                     |
# | Case marker | A case marker (`case`) is either a possessive marker, ...                                                                                                                                                                          |
# | Marker      | A marker (`mark`) is either a subordinating conjunction (e.g., although, because, while) that introduces an adverbial clause modifier, or a subordinating conjunction, if, that, or whether, that introduces a clausal complement. |
#
#
# ### Miscellaneous
#
# |                        |                                                                                                                                                                                                                |
# |------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Unclassified dependent | An unclassified dependent (`dep`) is a dependent that does not satisfy conditions for any other dependency.                                                                                                    |
# | Meta modifier          | A meta modifier (`meta`) is code (1), embedded (2), or meta (3) information that is randomly inserted in a phrase or clause.                                                                                   |
# | Parenthetical modifier | A parenthetical modifier (`parataxis`) is an embedded chunk, often but not necessarily surrounded by parenthetical notations (e.g,. brackets, quotes, commas, etc.), which gives side information to its head. |
# | Punctuation            | Any punctuation (`punct`) is assigned the dependency label PUNCT.                                                                                                                                              |
# | Root                   | A root (`root`) is the root of a tree that does not depend on any node in the tree but the artificial root node.                                                                                               |

# %% [markdown]
# ## Experiments

# %%
import functools
import spacy
from spacy import displacy
import coreferee

# %%
nlp = spacy.load("en_core_web_trf")

# %%
def print_deps(doc):
    for token in doc:
        print(f"{token.text} -- {token.pos_}")
        print(f"\tDEP: {token.dep_}")
        print(f"\tHEAD: {token.head.text}")
        
def render_deps(doc, compact=True, options=None):
    if not options: options = {}
    displacy.render(doc, style="dep", jupyter=True, options={'compact': compact, **options})
    
def cprint(*objs, color=0, sep="", end='\n'):
    to_print = f"\033[9{color}m" + sep.join(map(str, objs))
    print(to_print, end=end)

# %%
sample = "Autonomous cars shift insurance liability toward manufacturers"
doc = nlp(sample)
print(sample)
print("------")
print_deps(doc)
# Out:
# Autonomous cars shift insurance liability toward manufacturers
# ------
# Autonomous -- ADJ
# 	DEP: amod
# 	HEAD: cars
# cars -- NOUN
# 	DEP: nsubj
# 	HEAD: shift
# shift -- VERB
# 	DEP: ROOT
# 	HEAD: shift
# insurance -- NOUN
# 	DEP: compound
# 	HEAD: liability
# liability -- NOUN
# 	DEP: dobj
# 	HEAD: shift
# toward -- ADP
# 	DEP: prep
# 	HEAD: shift
# manufacturers -- NOUN
# 	DEP: pobj
# 	HEAD: toward
# C:\Users\tyler\projects\Atlas\venv\lib\site-packages\torch\autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %% [markdown]
# Assuming subject is **autonomous cars**, and object is **insurance liability**, we need to extract autonomous cars, insurance liability, and the relationship of "shift toward manufacturers."
#
# This is achieved with cars recognized as `nsubj`, autonomous as its `amod` child. "Shift" is recognized as the root verb. "Liability" is recognized as `dobj`, with "insurance" as child. "toward manufacturers" is recognized as child of shift.

# %%
render_deps(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dd0e71325af04eb6bd7e676aa09d3e47-0" class="displacy" width="1100" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Autonomous</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">cars</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">shift</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">insurance</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">liability</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">toward</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">manufacturers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-1" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,229.0 L208,221.0 216,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-2" stroke-width="2px" d="M512,227.0 512,202.0 644.0,202.0 644.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,229.0 L508,221.0 516,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-3" stroke-width="2px" d="M362,227.0 362,177.0 647.0,177.0 647.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M647.0,229.0 L651.0,221.0 643.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-4" stroke-width="2px" d="M362,227.0 362,152.0 800.0,152.0 800.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M800.0,229.0 L804.0,221.0 796.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-5" stroke-width="2px" d="M812,227.0 812,202.0 944.0,202.0 944.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dd0e71325af04eb6bd7e676aa09d3e47-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M944.0,229.0 L948.0,221.0 940.0,221.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Pipeline and Processing

# %% [markdown]
# ![image.png](attachment:eab42910-05c3-41b4-ac71-cc08ee1d3ce6.png)

# %%
full_text = """
The queen angelfish (Holacanthus ciliaris), also known as the blue angelfish, golden angelfish, or 
yellow angelfish, is a species of marine angelfish found in the western Atlantic Ocean. It is a 
benthic (ocean floor) warm-water species that lives in coral reefs. It is recognized by its blue 
and yellow coloration and a distinctive spot or "crown" on its forehead. This crown distinguishes 
it from the closely related and similar-looking Bermuda blue angelfish (Holacanthus bermudensis), 
with which it overlaps in range and can interbreed.Adult queen angelfish are selective feeders 
and primarily eat sponges. Their social structure consists of harems which include one male and 
up to four females. They live within a territory where the females forage separately and are 
tended to by the male. Breeding in the species occurs near a full moon. The transparent eggs 
are pelagic and float in the water, hatching after 15–20 hours. Juveniles of the species have 
different coloration than adults and act as cleaner fish. The queen angelfish is popular in 
the aquarium trade and has been a particularly common exported species from Brazil. In 2010, 
the queen angelfish was assessed as least concern by the International Union for 
Conservation of Nature as the wild population appeared to be stable.
""".replace('\n', '')
full_text
# Out:
# 'The queen angelfish (Holacanthus ciliaris), also known as the blue angelfish, golden angelfish, or yellow angelfish, is a species of marine angelfish found in the western Atlantic Ocean. It is a benthic (ocean floor) warm-water species that lives in coral reefs. It is recognized by its blue and yellow coloration and a distinctive spot or "crown" on its forehead. This crown distinguishes it from the closely related and similar-looking Bermuda blue angelfish (Holacanthus bermudensis), with which it overlaps in range and can interbreed.Adult queen angelfish are selective feeders and primarily eat sponges. Their social structure consists of harems which include one male and up to four females. They live within a territory where the females forage separately and are tended to by the male. Breeding in the species occurs near a full moon. The transparent eggs are pelagic and float in the water, hatching after 15–20 hours. Juveniles of the species have different coloration than adults and act as cleaner fish. The queen angelfish is popular in the aquarium trade and has been a particularly common exported species from Brazil. In 2010, the queen angelfish was assessed as least concern by the International Union for Conservation of Nature as the wild population appeared to be stable.'

# %% [markdown]
# ### Merging phrases

# %%
def merge_phrases(doc):
    with doc.retokenize() as retokenizer:
        for np in list(doc.noun_chunks):
            attrs = {
                "tag": np.root.tag_,
                "lemma": np.root.lemma_,
                "ent_type": np.root.ent_type_,
            }
            retokenizer.merge(np, attrs=attrs)
    return doc

# %%
long_text2 = "Adult queen angelfish are selective feeders and primarily eat sponges."
long_doc2 = nlp(long_text2)

# %%
render_deps(long_doc2)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="82d5daeea84f43c59bf1a09f04c645fa-0" class="displacy" width="1550" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Adult</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">queen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">angelfish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">selective</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">feeders</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">primarily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">eat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">sponges.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-0" stroke-width="2px" d="M62,302.0 62,252.0 344.0,252.0 344.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-1" stroke-width="2px" d="M212,302.0 212,277.0 341.0,277.0 341.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,304.0 L208,296.0 216,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-2" stroke-width="2px" d="M362,302.0 362,277.0 491.0,277.0 491.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,304.0 L358,296.0 366,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-3" stroke-width="2px" d="M662,302.0 662,277.0 791.0,277.0 791.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-4" stroke-width="2px" d="M512,302.0 512,252.0 794.0,252.0 794.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M794.0,304.0 L798.0,296.0 790.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-5" stroke-width="2px" d="M512,302.0 512,227.0 947.0,227.0 947.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M947.0,304.0 L951.0,296.0 943.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-6" stroke-width="2px" d="M1112,302.0 1112,277.0 1241.0,277.0 1241.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1112,304.0 L1108,296.0 1116,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-7" stroke-width="2px" d="M512,302.0 512,202.0 1250.0,202.0 1250.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1250.0,304.0 L1254.0,296.0 1246.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-82d5daeea84f43c59bf1a09f04c645fa-0-8" stroke-width="2px" d="M1262,302.0 1262,277.0 1391.0,277.0 1391.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-82d5daeea84f43c59bf1a09f04c645fa-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1391.0,30

# %%
long_doc2_merged = merge_phrases(long_doc2)
render_deps(long_doc2_merged)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="7d5bf02544da4a9783323df433fc04a4-0" class="displacy" width="1100" height="362.0" direction="ltr" style="max-width: none; height: 362.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Adult queen angelfish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">selective feeders</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">primarily</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">eat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="272.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">sponges.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-0" stroke-width="2px" d="M62,227.0 62,202.0 194.0,202.0 194.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,229.0 L58,221.0 66,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-1" stroke-width="2px" d="M212,227.0 212,202.0 344.0,202.0 344.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M344.0,229.0 L348.0,221.0 340.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-2" stroke-width="2px" d="M212,227.0 212,177.0 497.0,177.0 497.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M497.0,229.0 L501.0,221.0 493.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-3" stroke-width="2px" d="M662,227.0 662,202.0 794.0,202.0 794.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,229.0 L658,221.0 666,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-4" stroke-width="2px" d="M212,227.0 212,152.0 800.0,152.0 800.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M800.0,229.0 L804.0,221.0 796.0,221.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-7d5bf02544da4a9783323df433fc04a4-0-5" stroke-width="2px" d="M812,227.0 812,202.0 944.0,202.0 944.0,227.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-7d5bf02544da4a9783323df433fc04a4-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M944.0,229.0 L948.0,221.0 940.0,221.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### Merging Entities

# %%
full_text_doc = nlp(full_text)

# %%
render_deps(list(full_text_doc.sents)[-1], options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="90121bcac86d4891a106ff24ea8df88a-0" class="displacy" width="5250" height="537.0" direction="ltr" style="max-width: none; height: 537.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">2010,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">queen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">angelfish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">assessed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">least</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">concern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">International</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">Union</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">Conservation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3450">Nature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="3850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4050">wild</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4050">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">population</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4450">appeared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4650">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4650">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="4850">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="447.0">
#     <tspan class="displacy-word" fill="currentColor" x="5050">stable.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5050">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90121bcac86d4891a106ff24ea8df88a-0-0" stroke-width="2px" d="M62,402.0 62,302.0 1247.0,302.0 1247.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90121bcac86d4891a106ff24ea8df88a-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,404.0 L58,396.0 66,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-90121bcac86d4891a106ff24ea8df88a-0-1" stroke-width="2px" d="M62,402.0 62,368.6666666666667 241.0,368.6666666666667 241.0,402.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-90121bcac86d4891a106ff24ea8df88a-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M241.0,404.0 L245.0,396.0 237.0,396.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arro

# %%
displacy.render(list(full_text_doc.sents)[-1], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2010
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , the queen angelfish was assessed as least concern by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the International Union for Conservation of Nature
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  as the wild population appeared to be stable.</div></span>

# %% [markdown]
# ---
# In the last sentence of the document, we see that the "International Union for Conservation of Nature" is an entity but is not recognized as a phrase by the dependency parser. We can merge these together.

# %%
def merge_entities(doc):
    with doc.retokenize() as retokenizer:
        for ent in doc.ents:
            retokenizer.merge(ent)
    return doc

# %%
full_text_doc = merge_entities(merge_phrases(full_text_doc))

# %%
render_deps(list(full_text_doc.sents)[-1], options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="286d95bb3e3d41659b98050b02441d65-0" class="displacy" width="3050" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">2010,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">the queen angelfish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">assessed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">least concern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">the International Union for Conservation of Nature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">the wild population</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">appeared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">stable.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-0" stroke-width="2px" d="M62,302.0 62,202.0 850.0,202.0 850.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-1" stroke-width="2px" d="M62,302.0 62,268.6666666666667 244.0,268.6666666666667 244.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M244.0,304.0 L248.0,296.0 240.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-2" stroke-width="2px" d="M462,302.0 462,235.33333333333331 847.0,235.33333333333331 847.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,304.0 L458,296.0 466,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-3" stroke-width="2px" d="M662,302.0 662,268.6666666666667 844.0,268.6666666666667 844.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-4" stroke-width="2px" d="M862,302.0 862,268.6666666666667 1044.0,268.6666666666667 1044.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1044.0,304.0 L1048.0,296.0 1040.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-5" stroke-width="2px" d="M1062,302.0 1062,268.6666666666667 1244.0,268.6666666666667 1244.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-286d95bb3e3d41659b98050b02441d65-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1244.0,304.0 L1248.0,296.0 1240.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-286d95bb3e3d41659b98050b02441d65-0-6" stroke-width="2px" d="M862,302.0 862,235.33333333333331 1447.0,235.33333333333331 1447.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25

# %% [markdown]
# ### Constructing the pipeline

# %%
pipeline = spacy.load("en_core_web_trf")
pipeline.add_pipe("merge_entities") # built-in
pipeline.add_pipe("merge_noun_chunks")
# Out:
# <function spacy.pipeline.functions.merge_noun_chunks(doc: spacy.tokens.doc.Doc) -> spacy.tokens.doc.Doc>

# %%
full_text_doc = pipeline(full_text)

# %%
render_deps(list(full_text_doc.sents)[-1], options={'distance': 200})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c2fa7ba820774ffc80742607724d25bb-0" class="displacy" width="3050" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">2010,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">the queen angelfish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">assessed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">least concern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">by</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1650">the International Union for Conservation of Nature</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1650">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2050">the wild population</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">appeared</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2650">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">stable.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-0" stroke-width="2px" d="M62,302.0 62,202.0 850.0,202.0 850.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-1" stroke-width="2px" d="M62,302.0 62,268.6666666666667 244.0,268.6666666666667 244.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M244.0,304.0 L248.0,296.0 240.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-2" stroke-width="2px" d="M462,302.0 462,235.33333333333331 847.0,235.33333333333331 847.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubjpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M462,304.0 L458,296.0 466,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-3" stroke-width="2px" d="M662,302.0 662,268.6666666666667 844.0,268.6666666666667 844.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">auxpass</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M662,304.0 L658,296.0 666,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-4" stroke-width="2px" d="M862,302.0 862,268.6666666666667 1044.0,268.6666666666667 1044.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1044.0,304.0 L1048.0,296.0 1040.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-5" stroke-width="2px" d="M1062,302.0 1062,268.6666666666667 1244.0,268.6666666666667 1244.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c2fa7ba820774ffc80742607724d25bb-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1244.0,304.0 L1248.0,296.0 1240.0,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c2fa7ba820774ffc80742607724d25bb-0-6" stroke-width="2px" d="M862,302.0 862,235.33333333333331 1447.0,235.33333333333331 1447.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25

# %% [markdown]
# ### Finding the subject/object

# %% [markdown]
# Given a set of sentences/paragraph, find subjects and objects in each sentence. When a subject/object matches the topic of the article, the sentence should be added to the knowledge graph with a link to the other entities in the sentence, only if other entities exist in the sentence.

# %%
# in the future, this will be found by parsing through the wikitext and looking for [[]] text.
relevant_objects = ["species", "marine angelfish", "atlantic ocean", 
                    "benthic", "coral reefs", "holacanthus bermudensis", 
                    "sponges", "harems", "territory", "breeding", 
                    "full moon", "eggs", "pelagic", "cleaner fish", 
                    "aquarium trade", "brazil", "least concern", 
                    "international union for conservation of nature"]

# %%
def get_subjects_objects(doc):
    """Gets a list of subjects with each element corresponding to a sentence in the doc.
    Each element is an array [nsubj|nsubjpass] of spacy tokens.""" 
    return [[tok for tok in sent if tok.dep_ in ['nsubj', 'nsubjpass', 'dobj', 'pobj']] for sent in doc.sents]

# %%
for sent_subj_objs, sent in zip(get_subjects_objects(full_text_doc), full_text_doc.sents):
    for subj_obj in sent_subj_objs:
        cprint(f"{subj_obj} - type:{subj_obj.dep_} - head:{subj_obj.head} - i:{subj_obj.i - sent.start}", color=3)
    cprint("\t", sent, color=0)
# Out:
# The queen angelfish - type:nsubj - head:is - i:0
# the blue angelfish - type:pobj - head:as - i:8
# marine angelfish - type:pobj - head:of - i:18
# the western Atlantic Ocean - type:pobj - head:in - i:21
# 	The queen angelfish (Holacanthus ciliaris), also known as the blue angelfish, golden angelfish, or yellow angelfish, is a species of marine angelfish found in the western Atlantic Ocean.
# It - type:nsubj - head:is - i:0
# that - type:nsubj - head:lives - i:3
# coral reefs - type:pobj - head:in - i:6
# 	It is a benthic (ocean floor) warm-water species that lives in coral reefs.
# It - type:nsubjpass - head:recognized - i:0
# its blue and yellow coloration - type:pobj - head:by - i:4
# its forehead - type:pobj - head:on - i:11
# 	It is recognized by its blue and yellow coloration and a distinctive spot or "crown" on its forehead.
# This crown - type:nsubj - head:distinguishes - i:0
# it - type:dobj - head:distinguishes - i:2
# the closely related and similar-looking Bermuda blue angelfish - type:pobj - head:from - i:4
# which - type:pobj - head:with - i:10
# it - type:nsubj - head:overlaps - i:11
# range - type:pobj - head:in - i:14
# 	This crown distinguishes it from the closely related and similar-looking Bermuda blue angelfish (Holacanthus bermudensis), with which it overlaps in range and can interbreed.
# Adult queen angelfish - type:nsubj - head:are - i:0
# sponges - type:dobj - head:eat - i:6
# 	Adult queen angelfish are selective feeders and primarily eat sponges.
# Their social structure - type:nsubj - head:consists - i:0
# harems - type:pobj - head:of - i:3
# which - type:nsubj - head:include - i:4
# one male - type:dobj - head:include - i:6
# 	Their social structure consists of harems which include one male and up to four females.
# They - type:nsubj - head:live - i:0
# a territory - type:pobj - head:within - i:3
# the females - type:nsubj - head:forage - i:5
# the male - type:pobj - head:by - i:13
# 	They live within a territory where the females forage separately and are tended to by the male.
# Breeding - type:nsubj - head:occurs - i:0
# the species - type:pobj - head:in - i:2
# a full moon - type:pobj - head:near - i:5
# 	Breeding in the species occurs near a full moon.
# The transparent eggs - type:nsubj - head:are - i:0
# the water - type:pobj - head:in - i:6
# 15–20 hours - type:pobj - head:after - i:10
# 	The transparent eggs are pelagic and float in the water, hatching after 15–20 hours.
# Juveniles - type:nsubj - head:have - i:0
# the species - type:pobj - head:of - i:2
# different coloration - type:dobj - head:have - i:4
# adults - type:pobj - head:than - i:6
# cleaner fish - type:pobj - head:as - i:10
# 	Juveniles of the species have different coloration than adults and act as cleaner fish.
# The queen angelfish - type:nsubj - head:is - i:0
# the aquarium trade - type:pobj - head:in - i:4
# Brazil - type:pobj - head:from - i:10
# 	The queen angelfish is popular in the aquarium trade and has been a particularly common exported species from Brazil.
# 2010 - type:pobj - head:In - i:1
# the queen angelfish - type:nsubjpass - head:assessed - i:3
# least concern - type:pobj - head:as - i:7
# the International Union for Conservation of Nature - type:pobj - head:by - i:9
# the wild population - type:nsubj - head:appeared - i:11
# 	In 2010, the queen angelfish was assessed as least concern by the International Union for Conservation of Nature as the wild population appeared to be stable.

# %% [markdown]
# ### Pronoun resolution

# %% [markdown]
# I'll just use the `coreferee` plugin to resolve pronouns.

# %%
pipeline.add_pipe('coreferee')

# %%
doc = pipeline("The device that reads from a magnetic drive and writes data to it is called a disk.")

# %%
def render_corefs(doc):
    for sent in doc.sents:
        for token in sent:
            if token.pos_ == 'NOUN':
                cprint(f"{token} ({token.i})", color=3, end=' ')
            elif token.pos_ == 'PRON':
                cprint(f"{token} ({token.i})", color=2, end=' ')
            else:
                cprint(token, end=' ')
        print('\n')
    doc._.coref_chains.print()

# %%
render_corefs(doc)
# Out:
# The device (0) that (1) reads from a magnetic drive (4) and writes data (7) to it (9) is called a disk (12) .
#
# 0: a magnetic drive(4), it(9)

# %%
long_doc = '''
Germany, formally the Federal Republic of Germany, is a country in Central Europe. 
It is the second most populous country in Europe after Russia, and the most populous member state of the European Union. 
Germany is situated between the Baltic and North seas to the north, and the Alps to the south; it covers an area of 357,022 square kilometres (137,847 sq mi), with a population of over 83 million within its 16 constituent states. 
Germany borders Denmark to the north, Poland and the Czech Republic to the east, Austria and Switzerland to the south, and France, Luxembourg, Belgium, and the Netherlands to the west. 
The nation's capital and largest city is Berlin and its financial centre is Frankfurt; the largest urban area is the Ruhr. 
Germany is a great power with a strong economy; it has the largest economy in Europe, the world's fourth-largest economy by nominal GDP and the fifth-largest by PPP. 
As a global leader in several industrial, scientific and technological sectors, it is both the world's third-largest exporter and importer of goods. 
As a developed country, which ranks highly on the Human Development Index, it offers social security and a universal health care system, environmental protections, a tuition-free university education, and it is ranked as 18th most peaceful country in the world. 
Germany is a member of the United Nations, NATO, the G7, the G20 and the OECD. It has the third-greatest number of UNESCO World Heritage Sites. 
'''

# %%
render_corefs(pipeline(long_doc))
# Out:
#  Germany , formally the Federal Republic of Germany , is a country (6) in Central Europe .
#
#
#  It (11) is the second most populous country (13) in Europe after Russia , and the most populous member state (20) of the European Union .
#
#
#  Germany is situated between the Baltic and North seas (29) to the north (31) , and the Alps to the south (36) ; it (38) covers an area (40) of 357,022 square kilometres (42) ( 137,847 sq mi (44) ) , with a population (48) of over 83 million within its 16 constituent states (54) .
#
#
#  Germany borders Denmark to the north (61) , Poland and the Czech Republic to the east (67) , Austria and Switzerland to the south (73) , and France , Luxembourg , Belgium , and the Netherlands to the west (85) .
#
#
#  The nation's capital (88) and largest city (90) is Berlin and its financial centre (94) is Frankfurt ; the largest urban area (98) is the Ruhr .
#
#
#  Germany is a great power (105) with a strong economy (107) ; it (109) has the largest economy (111) in Europe , the world's fourth-largest economy (115) by nominal GDP and the fifth - largest by PPP .
#  As a global leader (128) in several industrial, scientific and technological sectors (130) , it (132) is both the world's third-largest exporter (134) and importer (136) of goods (138) .
#  As a developed country (142) , which (144) ranks highly on the Human Development Index , it (150) offers social security (152) and a universal health care system (154) , environmental protections (156) , a tuition-free university education (158) , and it (161) is ranked as 18th most peaceful country (165) in the world (167) .
#  Germany is a member (172) of the United Nations , NATO , the G7 , the G20 and the OECD .
#
# It (184) has the third-greatest number (186) of UNESCO World Heritage Sites .
#
#
#
#
# 0: Germany(1), It(11), Germany(25), it(38), Germany(57), Germany(103), it(109), it(132), Germany(170), It(184)
# 1: Central Europe(8), Europe(15)
# 2: the Human Development Index(148), it(150), it(161)

# %% [markdown]
# Here it **incorrectly** identifies "Human Development Index" as the antecedent.

# %%
long_doc2 = '''
The Germanic tribes are thought to date from the Nordic Bronze Age or the Pre-Roman Iron Age.
From southern Scandinavia and north Germany, they expanded south, east, and west, coming into contact with the Celtic, Iranian, Baltic, and Slavic tribes.
Under Augustus, the Roman Empire began to invade lands inhabited by the Germanic tribes, creating a short-lived Roman province of Germania between the Rhine and Elbe rivers. 
In 9 AD, three Roman legions were defeated by Arminius. By 100 AD, when Tacitus wrote Germania, Germanic tribes had settled along the Rhine and the Danube (the Limes Germanicus), occupying most of modern Germany. 
However, Baden Württemberg, southern Bavaria, southern Hesse and the western Rhineland had been incorporated into Roman provinces. 
Around 260, Germanic peoples broke into Roman-controlled lands.
After the invasion of the Huns in 375, and with the decline of Rome from 395, Germanic tribes moved farther southwest: the Franks established the Frankish Kingdom and pushed east to subjugate Saxony and Bavaria, and areas of what is today eastern Germany were inhabited by Western Slavic tribes.
'''

# %%
render_corefs(pipeline(long_doc2))
# Out:
#  The Germanic tribes (1) are thought to date from the Nordic Bronze Age or the Pre-Roman Iron Age .
#
#
#  From southern Scandinavia and north Germany , they (17) expanded south , east (21) , and west (24) , coming into contact (28) with the Celtic, Iranian, Baltic, and Slavic tribes (30) .
#
#
#  Under Augustus , the Roman Empire began to invade lands (40) inhabited by the Germanic tribes (43) , creating a short-lived Roman province (46) of Germania between the Rhine and Elbe rivers (50) .
#
#
#  In 9 AD (54) , three Roman legions (56) were defeated by Arminius .
#
# By 100 AD (63) , when Tacitus wrote Germania , Germanic tribes (70) had settled along the Rhine and the Danube ( the Limes Germanicus ) , occupying most of modern Germany .
#
#
#  However , Baden Württemberg , southern Bavaria , southern Hesse and the western Rhineland had been incorporated into Roman provinces (100) .
#
#
#  Around 260 , Germanic peoples (105) broke into Roman-controlled lands (108) .
#
#
#  After the invasion (112) of the Huns in 375 , and with the decline (120) of Rome from 395 , Germanic tribes (126) moved farther southwest : the Franks established the Frankish Kingdom and pushed east to subjugate Saxony and Bavaria , and areas (144) of what (146) is today (148) eastern Germany were inhabited by Western Slavic tribes (153) .
#
#
#
#
# 0: The Germanic tribes(1), they(17)
# 1: Germania(48), Germania(68)
# 2: southern Bavaria(91), Bavaria(141)

# %% [markdown]
# This is fine.

# %% [markdown]
# #### Comparing Coreferee models

# %% [markdown]
# Compare it to models `sm`, and `lg`.

# %%
pipeline_sm = spacy.load("en_core_web_sm")
pipeline_sm.add_pipe("merge_entities")
pipeline_sm.add_pipe("merge_noun_chunks")
pipeline_sm.add_pipe("coreferee")

pipeline_lg = spacy.load("en_core_web_lg")
pipeline_lg.add_pipe("merge_entities")
pipeline_lg.add_pipe("merge_noun_chunks")
pipeline_lg.add_pipe("coreferee")

# %%
render_corefs(pipeline_sm(long_doc))
# Out:
# Germany , formally the Federal Republic of Germany , is a country (5) in Central Europe .
#
#
#  It (10) is the second most populous country (12) in Europe after Russia , and the most populous member state (19) of the European Union .
#
#
#  Germany is situated between the Baltic and North seas (28) to the north (30) , and the Alps to the south (36) ; it (38) covers an area (40) of 357,022 square kilometres (42) ( 137,847 sq mi ) , with a population (50) of over 83 million within its 16 constituent states (54) .
#
#
# Germany borders (56) Denmark to the north (59) , Poland and the Czech Republic to the east (65) , Austria and Switzerland to the south (71) , and France , Luxembourg , Belgium , and the Netherlands to the west (83) .
#
#
#  The nation's capital (86) and largest city (88) is Berlin and its financial centre (92) is Frankfurt ; the largest urban area (96) is the Ruhr .
#
#
#  Germany is a great power (103) with a strong economy (105) ; it (107) has the largest economy (109) in Europe , the world's fourth-largest economy (113) by nominal GDP and the fifth - largest by PPP .
#
#
#  As a global leader (126) in several industrial, scientific and technological sectors (128) , it (130) is both the world's third-largest exporter (132) and importer (134) of goods (136) .
#
#
#  As a developed country (140) , which (142) ranks highly on the Human Development Index , it (148) offers social security (150) and a universal health care system (152) , environmental protections (154) , a tuition-free university education (156) , and it (159) is ranked as 18th most peaceful country (163) in the world (165) .
#
#
#  Germany is a member (170) of the United Nations , NATO , the G7 , the G20 and the OECD .
#
# It (182) has the third-greatest number (184) of UNESCO World Heritage Sites .
#
#
#
#
# 0:
# Germany(0), It(10), Germany(24), it(38)
# 1: Central Europe(7), Europe(14)
# 2: Germany(101), it(107), it(130), it(148), it(159), Germany(168), It(182)

# %%
render_corefs(pipeline_lg(long_doc))
# Out:
#  Germany , formally the Federal Republic of Germany , is a country (6) in Central Europe .
#
#
#  It (11) is the second most populous country (13) in Europe after Russia , and the most populous member state (20) of the European Union .
#
#
#  Germany is situated between the Baltic and North seas (29) to the north (31) , and the Alps to the south (37) ; it (39) covers an area (41) of 357,022 square kilometres (43) ( 137,847 sq mi ) , with a population (49) of over 83 million within its 16 constituent states (53) .
#
#
#  Germany borders Denmark to the north (60) , Poland and the Czech Republic to the east (66) , Austria and Switzerland to the south (72) , and France , Luxembourg , Belgium , and the Netherlands to the west (84) .
#
#
#  The nation's capital (87) and largest city (89) is Berlin and its financial centre (93) is Frankfurt ; the largest urban area (97) is the Ruhr .
#
#
#  Germany is a great power (104) with a strong economy (106) ; it (108) has the largest economy (110) in Europe , the world's fourth-largest economy (114) by nominal GDP (116) and the fifth - largest by PPP .
#
#
#  As a global leader (127) in several industrial, scientific and technological sectors (129) , it (131) is both the world's third-largest exporter (133) and importer (135) of goods (137) .
#
#
#  As a developed country (141) , which (143) ranks highly on the Human Development Index , it (149) offers social security (151) and a universal health care system (153) , environmental protections (155) , a tuition-free university education (157) , and it (160) is ranked as 18th most peaceful country (163) in the world (165) .
#
#
#  Germany is a member (170) of the United Nations , NATO , the G7 , the G20 and the OECD .
#
# It (182) has the third-greatest number (184) of UNESCO World Heritage Sites .
#
#
#
#
# 0: Germany(1), It(11), Germany(25), it(39)
# 1: Central Europe(8), Europe(15)
# 2: Germany(102), it(108), it(131), it(149), it(160), Germany(168), It(182)

# %% [markdown]
# Here both the small and large pipelines correctly identify Germany instad of Human Development Index.

# %%
render_corefs(pipeline_sm(long_doc2))
# Out:
#  The Germanic tribes (1) are thought to date (5) from the Nordic Bronze Age or the Pre-Roman Iron Age .
#
#
#  From southern Scandinavia and north Germany , they (17) expanded south , east , and west (24) , coming into contact (28) with the Celtic, Iranian, Baltic, and Slavic tribes (30) .
#
#
#  Under Augustus , the Roman Empire began to invade lands (40) inhabited by the Germanic tribes (43) , creating a short-lived Roman province (46) of Germania between the Rhine and Elbe rivers (50) .
#
#
#  In 9 AD (54) , three Roman legions (56) were defeated by Arminius .
#
# By 100 AD (63) , when Tacitus wrote Germania , Germanic tribes (70) had settled along the Rhine and the Danube ( the Limes Germanicus ) , occupying most of modern Germany .
#
#
#  However , Baden Württemberg , southern Bavaria , southern Hesse and the western Rhineland had been incorporated into Roman provinces (100) .
#
#
#  Around 260 , Germanic peoples (106) broke into Roman-controlled lands (109) .
#
#
#  After the invasion (113) of the Huns in 375 , and with the decline (121) of Rome from 395 , Germanic tribes (127) moved farther southwest : the Franks established the Frankish Kingdom and pushed east to subjugate Saxony and Bavaria , and areas (145) of what (147) is today (149) eastern Germany were inhabited by Western Slavic tribes (154) .
#
#
# 0: The Germanic tribes(1), they(17)
# 1: Germania(48), Germania(68)
# 2: southern Bavaria(91), Bavaria(142)

# %%
render_corefs(pipeline_lg(long_doc2))
# Out:
#  The Germanic tribes (1) are thought to date (5) from the Nordic Bronze Age or the Pre-Roman Iron Age .
#
#
#  From southern Scandinavia and north Germany , they (15) expanded south , east (19) , and west (22) , coming into contact (26) with the Celtic, Iranian, Baltic, and Slavic tribes (28) .
#
#
#  Under Augustus , the Roman Empire began to invade lands (38) inhabited by the Germanic tribes (41) , creating a short-lived Roman province (44) of Germania between the Rhine and Elbe rivers (48) .
#
#
#  In 9 AD (52) , three Roman legions (54) were defeated by Arminius .
#
# By 100 AD (61) , when Tacitus wrote Germania , Germanic tribes (68) had settled along the Rhine and the Danube ( the Limes Germanicus ) , occupying most of modern Germany .
#
#
#  However , Baden Württemberg , southern Bavaria , southern Hesse and the western Rhineland had been incorporated into Roman provinces (98) .
#
#
#  Around 260 , Germanic peoples (104) broke into Roman-controlled lands (107) .
#
#
#  After the invasion (111) of the Huns in 375 , and with the decline (119) of Rome from 395 , Germanic tribes (125) moved farther southwest : the Franks established the Frankish Kingdom and pushed east to subjugate Saxony and Bavaria , and areas (143) of what (145) is today (147) eastern Germany were inhabited by Western Slavic tribes (152) .
#
#
#
#
# 0: The Germanic tribes(1), they(15)
# 1: Germania(46), Germania(66)
# 2: southern Bavaria(89), Bavaria(140)

# %% [markdown]
# The `trf` models don't add word vectors: maybe this is the reason for the discrepancy between lg and trf. Use `lg` model.

# %%
render_corefs(pipeline_sm(full_text))
# Out:
# The queen angelfish (0) ( Holacanthus ciliaris ) , also known as the blue angelfish (8) , golden angelfish (10) , or yellow angelfish (13) , is a species (16) of marine angelfish (18) found in the western Atlantic Ocean .
#
# It (23) is a benthic (ocean floor) warm-water species (25) that (26) lives in coral reefs (29) .
#
# It (31) is recognized by its blue and yellow coloration (35) and a distinctive spot (37) or "crown (39) " on its forehead (42) .
#
# This crown (44) distinguishes it (46) from the closely related and similar-looking Bermuda blue angelfish (48) ( Holacanthus bermudensis (50) ) , with which (54) it (55) overlaps in range (58) and can interbreed .
#
# Adult queen angelfish (63) are selective feeders (65) and primarily eat sponges (69) .
#
# Their social structure (71) consists of harems (74) which (75) include one male (77) and up to four females (79) .
#
# They (81) live within a territory (84) where the females (86) forage separately and are tended to by the male (94) .
#
# Breeding in the species (98) occurs near a full moon (101) .
#
# The transparent eggs (103) are pelagic and float in the water (109) , hatching after 15–20 hours (113) .
#
# Juveniles (115) of the species (117) have different coloration (119) than adults (121) and act as cleaner fish (125) .
#
# The queen angelfish (127) is popular in the aquarium trade (131) and has been a particularly common exported species (135) from Brazil .
#
# In 2010 , the queen angelfish (142) was assessed as least concern (145) by the International Union for Conservation of Nature as the wild population (149) appeared to be stable .
#
# 0: The queen angelfish(0), It(31)
# 1: its forehead(42), it(46), it(55)
# 2: harems(74), They(81)

# %% [markdown]
# And this one is all over the place, all wrong.

# %% [markdown]
# #### Issues and Limitations

# %% [markdown]
# * No support for noun phrase pronouns (?). For example: "The bat is a nocturnal animal. The species sleeps in the day." Coreferee does not recognize "the species" as bat.
# * Completely inaccurate in certain cases.

# %% [markdown]
# ### AllenNLP

# %% [markdown]
# If we only need coreference resolution, we can experiment with other models, let's try AllenNLP.

# %%
import allennlp_models.tagging
from allennlp.predictors.predictor import Predictor

# %%
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/coref-spanbert-large-2021.03.10.tar.gz")
# Out:
# error loading _jsonnet (this is expected on Windows), treating C:\Users\tyler\AppData\Local\Temp\tmpljry6q6_\config.json as plain json
# Some weights of BertModel were not initialized from the model checkpoint at SpanBERT/spanbert-large-cased and are newly initialized: ['bert.pooler.dense.weight', 'bert.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
allen_result = predictor.predict(
    document="Paul Allen was born on January 21, 1953, in Seattle, Washington, to Kenneth Sam Allen and Edna Faye Allen. Allen attended Lakeside School, a private school in Seattle, where he befriended Bill Gates, two years younger, with whom he shared an enthusiasm for computers. Paul and Bill used a teletype terminal at their high school, Lakeside, to develop their programming skills on several time-sharing computer systems."
)

# %%
def find_token_index_in_cluster_list(token_index, clusters):
    "returns color to print if found based on cluster, None if not found. Only 6 colors available."
    for i, cluster in enumerate(clusters):
        for c in cluster:
            if token_index in c:
                return i % 6 + 1
    return None

def get_antecedent_for_cluster_element(prediction, cluster_element):
    for i, (start, end) in enumerate(prediction['top_spans']):
        if start == cluster_element[0] and end == cluster_element[1]:
            antecedent_indices_index = prediction['predicted_antecedents'][i]
            if antecedent_indices_index == -1:
                return None
            top_span_index = prediction['antecedent_indices'][i][antecedent_indices_index]
            ante_start_index, ante_end_index = prediction['top_spans'][top_span_index]
            return ' '.join(prediction["document"][ante_start_index:ante_end_index + 1]) # range is inclusive. subscript inclusive
    return None # this will never happen, but keep it just for completeness 

def render_result(prediction):
    for i, token in enumerate(prediction['document']):
        if (color := find_token_index_in_cluster_list(i, prediction['clusters'])):
            cprint(f'{token} ({i})', color=color, end=' ')
        else:
            cprint(token, end=' ')
    print('\n')
    for i, cluster in enumerate(prediction['clusters']):
        cprint(f"\nCluster {i}\n")
        color = i % 6 + 1
        for j, c in enumerate(cluster):
            antecedent = get_antecedent_for_cluster_element(prediction, c)
            cprint(f'indices: {c}', color=color)
            cprint('\ttext: ' + ' '.join(prediction['document'][c[0]:c[1] + 1]))
            if antecedent:
                cprint(f"\tante: {antecedent}")
            else:
                cprint("\t__ANTECEDENT__")

# %%
render_result(allen_result)
# Out:
# Paul (0) Allen (1) was born on January 21 , 1953 , in Seattle (11) , Washington (13) , to Kenneth Sam Allen and Edna Faye Allen . Allen (24) attended Lakeside (26) School , a private school in Seattle (33) , where he (36) befriended Bill (38) Gates , two years younger , with whom he (47) shared an enthusiasm for computers (52) . Paul (54) and Bill (56) used a teletype terminal at their (62) high school , Lakeside , (67) to develop their (70) programming skills on several time - sharing computer systems .
#
#
# Cluster 0
#
# indices: [0, 1]
# 	text: Paul Allen
# 	__ANTECEDENT__
# indices: [24, 24]
# 	text: Allen
# 	ante: Paul Allen
# indices: [36, 36]
# 	text: he
# 	ante: Allen
# indices: [47, 47]
# 	text: he
# 	ante: Allen
# indices: [54, 54]
# 	text: Paul
# 	ante: Paul Allen
#
# Cluster 1
#
# indices: [11, 13]
# 	text: Seattle , Washington
# 	__ANTECEDENT__
# indices: [33, 33]
# 	text: Seattle
# 	ante: Seattle , Washington
#
# Cluster 2
#
# indices: [38, 52]
# 	text: Bill Gates , two years younger , with whom he shared an enthusiasm for computers
# 	__ANTECEDENT__
# indices: [56, 56]
# 	text: Bill
# 	ante: Bill Gates , two years younger , with whom he shared an enthusiasm for computers
#
# Cluster 3
#
# indices: [54, 56]
# 	text: Paul and Bill
# 	__ANTECEDENT__
# indices: [62, 62]
# 	text: their
# 	ante: Paul and Bill
# indices: [70, 70]
# 	text: their
# 	ante: Paul and Bill
#
# Cluster 4
#
# indices: [26, 52]
# 	text: Lakeside School , a private school in Seattle , where he befriended Bill Gates , two years younger , with whom he shared an enthusiasm for computers
# 	__ANTECEDENT__
# indices: [62, 67]
# 	text: their high school , Lakeside ,
# 	ante: Lakeside School , a private school in Seattle , where he befriended Bill Gates , two years younger , with whom he shared an enthusiasm for computers

# %% [markdown]
# #### Interpreting AllenNLP output

# %% [markdown]
# `predictor.predict` returns an object with keys:
#
# |Key|Description|
# |-|-|
# |`top_spans`|A tensor of shape `(batch_size, num_spans_to_keep, 2)` representing the start and end word indices of the top spans that survived the pruning stage.|
# |`antecedent_indices`|A tensor of shape `(num_spans_to_keep, max_antecedents)` representing for each top span the index (with respect to top_spans) of the possible antecedents the model considered.|
# |`predicted_antecedents`|A tensor of shape `(batch_size, num_spans_to_keep)` representing, for each top span, the index (with respect to antecedent_indices) of the most likely antecedent. -1 means there was no predicted link.|
# |`clusters`|A tensor of shape `(batch_size, num_clusters, 2)` representing the start and end word indices of spans that corefer each other.|
#
# To find coreferred spans, iterate through clusters for each batch. Each cluster will reveal the start + end indices for each span that corefer each other. To find the antecedent of each span, find the **index `i`** it is located at in `top_spans`.
# > `cluster 1 -> span [5, 10]` `span [5, 10] found at index 3 in top_spans` `i = 3`.
#
# Go to `i` in `predicted_antecedents` and get value `j`. If -1, then the span is the antecedent.
# > `predicted_antecedents[3] = 4`
#
# Go to `i` in `antecedent_indices` and get value `antecedent_indices[i][j] = k`. This value is guaranteed to exist.
# > `antecedent_indices[3] = [1, 3, 4, 5, 6, 7, 8, 9, 11, 13, 14]` `antecedent_indices[3][4] = 6`
#
# Go to `top_spans[k]` to get antecedent span.
# > `top_spans[6] = [1, 3]`

# %% [markdown]
# #### Sample

# %%
long_doc2_result = predictor.predict(document=long_doc2)

# %%
render_result(long_doc2_result)
# Out:
#  The (1) Germanic tribes (3) are thought to date from the Nordic Bronze Age or the Pre - Roman Iron Age .
#  From southern Scandinavia and north Germany , they (29) expanded south , east , and west , coming into contact with the Celtic , Iranian , Baltic , and Slavic tribes .
#  Under Augustus , the Roman Empire began to invade lands inhabited by the (66) Germanic tribes (68) , creating a (71) short - lived Roman province of Germania between the Rhine and Elbe rivers (84) .
#  In 9 AD , three Roman legions were defeated by Arminius . By 100 AD , when Tacitus wrote Germania (106) , Germanic tribes had settled along the Rhine and the Danube ( the Limes Germanicus ) , occupying most of modern Germany .
#  However , Baden Württemberg , southern Bavaria , southern Hesse and the western Rhineland had been incorporated into Roman provinces .
#  Around 260 , Germanic peoples broke into Roman - controlled lands .
#  After the invasion of the Huns in 375 , and with the decline of Rome from 395 , Germanic tribes moved farther southwest : the Franks established the Frankish Kingdom and pushed east to subjugate Saxony and Bavaria , and areas of what is today eastern Germany were inhabited by Western Slavic tribes .
#
#
#
# Cluster 0
#
# indices: [1, 3]
# 	text: The Germanic tribes
# 	__ANTECEDENT__
# indices: [29, 29]
# 	text: they
# 	ante: The Germanic tribes
# indices: [66, 68]
# 	text: the Germanic tribes
# 	ante: they
#
# Cluster 1
#
# indices: [71, 84]
# 	text: a short - lived Roman province of Germania between the Rhine and Elbe rivers
# 	__ANTECEDENT__
# indices: [106, 106]
# 	text: Germania
# 	ante: a short - lived Roman province of Germania between the Rhine and Elbe rivers

# %%
full_text_result = predictor.predict(document=full_text)

# %%
render_result(full_text_result)
# Out:
# The (0) queen angelfish (2) ( Holacanthus ciliaris ) , also known as the blue angelfish , golden angelfish , or yellow angelfish , is a species of marine angelfish found in the western Atlantic Ocean . It (35) is a benthic ( ocean floor ) warm - water species that lives in coral reefs . It (53) is recognized by its (57) blue and yellow coloration and a (63) distinctive spot or " crown " on its (71) forehead (72) . This (74) crown (75) distinguishes it (77) from the closely related and similar - looking Bermuda blue angelfish ( Holacanthus bermudensis ) , with which it (96) overlaps in range and can interbreed . Adult (104) queen angelfish (106) are selective feeders and primarily eat sponges . Their (115) social structure consists of harems which include one (123) male (124) and up (126) to four females (129) . They (131) live within a territory where the (137) females (138) forage separately and are tended to by the (146) male (147) . Breeding in the (151) species (152) occurs near a full moon . The transparent eggs are pelagic and float in the water , hatching after 15–20 hours . Juveniles of the (177) species (178) have different coloration than adults and act as cleaner fish . The (190) queen angelfish (192) is popular in the aquarium trade and has been a particularly common exported species from Brazil . In 2010 , the (213) queen angelfish (215) was assessed as least concern by the International Union for Conservation of Nature as the wild population appeared to be stable .
#
#
# Cluster 0
#
# indices: [0, 2]
# 	text: The queen angelfish
# 	__ANTECEDENT__
# indices: [35, 35]
# 	text: It
# 	ante: The queen angelfish
# indices: [53, 53]
# 	text: It
# 	ante: It
# indices: [57, 57]
# 	text: its
# 	ante: It
# indices: [71, 71]
# 	text: its
# 	ante: It
# indices: [77, 77]
# 	text: it
# 	ante: It
# indices: [96, 96]
# 	text: it
# 	ante: It
# indices: [151, 152]
# 	text: the species
# 	ante: It
# indices: [177, 178]
# 	text: the species
# 	ante: the species
# indices: [190, 192]
# 	text: The queen angelfish
# 	ante: the species
# indices: [213, 215]
# 	text: the queen angelfish
# 	ante: The queen angelfish
#
# Cluster 1
#
# indices: [63, 72]
# 	text: a distinctive spot or " crown " on its forehead
# 	__ANTECEDENT__
# indices: [74, 75]
# 	text: This crown
# 	ante: a distinctive spot or " crown " on its forehead
#
# Cluster 2
#
# indices: [104, 106]
# 	text: Adult queen angelfish
# 	__ANTECEDENT__
# indices: [115, 115]
# 	text: Their
# 	ante: Adult queen angelfish
#
# Cluster 3
#
# indices: [123, 129]
# 	text: one male and up to four females
# 	__ANTECEDENT__
# indices: [131, 131]
# 	text: They
# 	ante: one male and up to four females
#
# Cluster 4
#
# indices: [126, 129]
# 	text: up to four females
# 	__ANTECEDENT__
# indices: [137, 138]
# 	text: the females
# 	ante: up to four females
#
# Cluster 5
#
# indices: [123, 124]
# 	text: one male
# 	__ANTECEDENT__
# indices: [146, 147]
# 	text: the male
# 	ante: one male

# %%
render_result(predictor.predict(document="While he was searching for his glasses, John stubbed his toe."))
# Out:
# While he (1) was searching for his (5) glasses , John (8) stubbed his toe .
#
#
# Cluster 0
#
# indices: [1, 1]
# 	text: he
# 	__ANTECEDENT__
# indices: [5, 5]
# 	text: his
# 	ante: he
# indices: [8, 8]
# 	text: John
# 	ante: he

# %% [markdown]
# #### Optimizing Antecedent Searching

# %% [markdown]
# If search for antecedents by iterating through `top_spans` for each cluster span, this can be very inefficient. Technically, we don't need to find the antecedent. Just need to find the subject of article.

# %% [markdown]
# ### Parsing Wikipedia

# %%
sample_wiki = """
The '''queen angelfish''' (''Holacanthus ciliaris''), also known as the '''blue angelfish''', '''golden angelfish''', or '''yellow angelfish''', is a [[species]] of [[Pomacanthidae|marine angelfish]] found in the western [[Atlantic Ocean]]. It is a [[benthic zone|benthic]] (ocean floor) warm-water species that lives in [[coral reef]]s. It is recognized by its blue and yellow coloration and a distinctive spot or "crown" on its forehead. This crown distinguishes it from the closely related and similar-looking Bermuda blue angelfish (''[[Holacanthus bermudensis]]''), with which it overlaps in range and can interbreed.

Adult queen angelfish are selective feeders and primarily eat [[sponge]]s. Their social structure consists of [[harem (zoology)|harems]] which include one male and up to four females. They live within a [[territory (animal)|territory]] where the females forage separately and are tended to by the male. [[Spawn (biology)|Breeding]] in the species occurs near a [[full moon]]. The transparent [[Ichthyoplankton|eggs]] float in the water until they hatch. Juveniles of the species have different coloration than adults and act as [[cleaner fish]].

The queen angelfish is popular in the [[Fishkeeping|aquarium trade]] and has been a particularly common exported species from [[Brazil]]. In 2010, the queen angelfish was assessed as [[least concern]] by the [[International Union for Conservation of Nature]] as the wild population appeared to be stable.
"""

# %% [markdown]
# Input text will be raw [wikitext](https://en.wikipedia.org/wiki/Help:Wikitext). Goal is to clean up the text, with all markup removed except outgoing links.

# %% [markdown]
# #### Wikitext Conversion

# %% [markdown]
# **General Rules**:

# %% [markdown]
# * For any kind of html, just remove the tag, and keep text.
# * For templates, keep the text according to template format. Define custom reader for templates.
#     * KV pairs should be handled specially for information extraction.
#     * String data from templates should be extracted as is without template syntax.
# * Newlines + tabs should be replaced by plain whitespace.

# %% [markdown]
# |Element|Format|HTML|Action|Template|
# |-|-|-|-|-|
# |Headings|`={0,6}...={0,6}`|h1-6|Remove|template exists, but should not be used in articles|
# |Horizontal Rule|----|hr|Remove||
# |Table of Contents|\_\_TOC\_\_, \_\_FORCE_TOC\_\_, \_\_NOTOC\_\_||Remove|Template exists {{TOC limit}}|
# |Line Breaks|`enter`|br, br/|Remove|template {{break}}, {{-}}, {{clear}}|
# |Unordered list|\*, \*\*, \*\*\*, ...|ul|Retain text. Handler|template {{plainlist}}, {{unbulleted list}}|
# |Ordered list|\#, \#\#, \#\#\#, ...|ol|Retain text. Handler||
# |Description list|; followed by :|dl, dt, dd|Retain text. Handler|template {{glossary}}, {{term}}, {{defn}}|
# |Indents|:, ::, :::, ...||Remove|template {{outdent}}, {{outdent2}}|
# |Blockquote||blockquote|Retain text|template {{quote}}|
# |Italics|''...''||Retain text||
# |Bold|'''...'''||Retain text||
# |Bold Italics|'''''...'''''||Retain text||
# |Small Caps|||Retain text|template {{smallcaps}}|
# |Code||code|Retain text||
# |Syntax Highlight||syntaxhighlight|Retain text||
# |Small text||small|Retain text||
# |Big text||big|Retain text||
# |Non breaking space|&nbsp;||Replace with whitespace|template {{nowrap}}|
# |Extra spacing|||Replace with whitespace|template {{pad}}|
# |Special Symbols|&\<spec\>;||Remove/Replace with whitespace||
# |Math||math|Remove|template {{math}}|
# |Pronunication aids|||Remove|template {{IPAc-en}}, {{respell}}|
