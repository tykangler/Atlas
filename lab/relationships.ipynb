# %% [markdown]
# # Relationship Mapping

# %% [markdown]
# This is to test out methods and brainstorm ways of finding relationships within annotated text. Initial ideas are:
# 1. Do not merge phrases.
# 2. Find the root dep of the link. (the root is defined as a token that has no inward links from tokens within the link)
# 3. Traverse links until finding a verb, **capture traversed text and link subtree text**
# 4. Check if verb is already in the subtree. If so, then stop traversing, note that there are very few cases where the verb is not the root.

# %%
import spacy
from termcolor import colored
from spacy.tokens import Doc, Span, Token
from spacy import displacy
from typing import Iterator

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## Functions

# %%
def render_deps(doc: Doc):
    displacy.render(list(doc.sents), style="dep", options={
        "compact": True,
        "bg": "#fff0",
        "color": "#EEE",
        "font": "consolas"
    })

# %%
def get_phrase_span(doc: Doc, phrase: str):
    index_found = doc.text.index(phrase)
    return doc.char_span(index_found, len(phrase) + index_found)

# %%
def get_relationship_for_span(span: Span):
    """
    Gets the next highest verb for the span and any intermediate tokens that may qualify the verb. If verb is already present in the subtree of the given span,
    then return the subtree
    inserts tokens into the beginning of the list until a verb token or aux token is reached. Add the verb or aux token, and break the loop
    if at any point a conjugating token is reached, (i.e. dep_ == "conj"), then the following phrases (e.g. the important ones) are part of a conjugated clause, and the next ancestor 
    is just the first part of the conjugated clause and should be skipped. However, if the next ancestor of a conjugated clause is actually a verb, then the verb rule should be followed.
    The verb should be inserted, and the loop should break.
    This handles cases such as "John ate an apple and an orange." orange -(conj)> apple -()> ate. apple should be skipped.
    "John served as kitchen staff and as hospitality.
    """
    tokens = []
    for token in span.subtree:
        tokens.append(token)
    if span.root.pos_ == "VERB" or span.root.pos_ == "AUX":
        return tokens
    is_conj = span.root.dep_ == "conj"
    for token in span.root.ancestors:
        if token.pos_ == "VERB" or token.pos_ == "AUX":
            tokens.insert(0, token)
            return tokens
        elif not is_conj:
            tokens.insert(0, token)
        elif is_conj:
            is_conj = False

        if token.dep_  == "conj":
            is_conj = True
    return None

# %%
def print_relationship(relationship: Iterator[Token], phrase: Span, detailed: bool=False):
    for token in relationship:
        if token.pos_ == 'VERB' or token.pos_ == "AUX" or detailed:
            print(f"{colored(token.text, 'green')} (POS:{token.pos_},DEP:{token.dep_},TAG:{token.tag_},Position={token.idx})", end=' ')
        else:
            print(f"{colored(token.text, 'blue')}", end=' ')
    print()
    print(f"Root: {colored(phrase.root, 'blue')}")
    print(f"Phrase: {colored(phrase.text, 'blue')}")

# %%
def render_phrase_relationship(doc: Doc, phrase: str, detailed: bool=False):
    phrase_span = get_phrase_span(doc, phrase)
    relationship = get_relationship_for_span(phrase_span)
    print_relationship(relationship, phrase_span, detailed)

# %%
class Extract:
    def __init__(self, text: str, links: Iterator[str]):
        self.text = text
        self.links = links

def render_multi_phrase_relationship(extracts: Iterator[Extract], expand_deps=False, detailed=False):
    docs = list(nlp.pipe(ext.text for ext in extracts))
    if expand_deps:
        for doc in docs:
            render_deps(doc)
    for (sent, doc) in zip(extracts, docs):
        print()
        print(sent.text)
        for link in sent.links:
            render_phrase_relationship(doc, link, detailed)

# %% [markdown]
# ## Initial Sample

# %% [markdown]
# Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.

# %%
text1 = "Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017."
linkText = "president of the United States"

# %%
doc1 = nlp(text1)
render_deps(doc1)
render_phrase_relationship(doc1, linkText)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="64fcced5b9984c18b33b51890278ae01-0" class="displacy" width="4250" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #EEE; background: #fff0; font-family: consolas; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Barack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">Hussein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Obama</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">II (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">August</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">4,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">1961)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">American</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">lawyer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">politician</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">served</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">44th</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">president</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">United</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">States</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">2009</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">2017.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64fcced5b9984c18b33b51890278ae01-0-0" stroke-width="2px" d="M62,302.0 62,277.0 191.0,277.0 191.0,302.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-64fcced5b9984c18b33b51890278ae01-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,304.0 L58,296.0 66,296.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-64fcced5b9984c18b33b51890278ae01-0-1" stroke-width="2px" d="M212,302.0 212,25
# served (POS:VERB,DEP:relcl,TAG:VBD,Position=87) as the 44th president of the United States
# Root: president
# Phrase: president of the United States

# %% [markdown]
# ## Long Samples

# %%
article = [
    Extract(
        text="Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.",
        links=["president of the United States"]
    ),
    Extract(
        text="A member of the Democratic Party, he was the first African-American president in U.S. history.",
        links=["African-American", "Democratic Party"]
    ),
    Extract(
        text="Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.",
        links=["U.S. senator", "Illinois", "Illinois state senator"]
    )
]

# %%
render_multi_phrase_relationship(article, False)
# Out:
# Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.
# served (POS:VERB,DEP:relcl,TAG:VBD,Position=87) as the 44th president of the United States
# Root: president
# Phrase: president of the United States
#
# A member of the Democratic Party, he was the first African-American president in U.S. history.
# was (POS:AUX,DEP:ROOT,TAG:VBD,Position=37) president African - American
# Root: American
# Phrase: African-American
# was (POS:AUX,DEP:ROOT,TAG:VBD,Position=37) member of the Democratic Party
# Root: Party
# Phrase: Democratic Party
#
# Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=17) as a U.S. senator representing (POS:VERB,DEP:acl,TAG:VBG,Position=42) Illinois from 2005 to 2008
# Root: senator
# Phrase: U.S. senator
# representing (POS:VERB,DEP:acl,TAG:VBG,Position=42) Illinois
# Root: Illinois
# Phrase: Illinois
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=17) as an Illinois state senator from 1997 to 2004
# Root: senator
# Phrase: Illinois state senator

# %%
article = [
    Extract("John served as kitchen staff and hospitality", ["kitchen staff", "hospitality"])
]

render_multi_phrase_relationship(article, True, True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e4d6bbe0660549aa818ab67f44faa43b-0" class="displacy" width="1100" height="287.0" direction="ltr" style="max-width: none; height: 287.0px; color: #EEE; background: #fff0; font-family: consolas; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">served</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">kitchen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">staff</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="197.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">hospitality</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-0" stroke-width="2px" d="M62,152.0 62,127.0 197.0,127.0 197.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,154.0 L58,146.0 66,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-1" stroke-width="2px" d="M212,152.0 212,127.0 347.0,127.0 347.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M347.0,154.0 L351.0,146.0 343.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-2" stroke-width="2px" d="M512,152.0 512,127.0 647.0,127.0 647.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,154.0 L508,146.0 516,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-3" stroke-width="2px" d="M362,152.0 362,102.0 650.0,102.0 650.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,154.0 L654.0,146.0 646.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-4" stroke-width="2px" d="M662,152.0 662,127.0 797.0,127.0 797.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M797.0,154.0 L801.0,146.0 793.0,146.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e4d6bbe0660549aa818ab67f44faa43b-0-5" stroke-width="2px" d="M662,152.0 662,102.0 950.0,102.0 950.0,152.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e4d6bbe0660549aa818ab67f44faa43b-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,154.0 L954.0,146.0 946.0,146.0" fill="currentColor"/>
# </g>
# </svg></span>
# John served as kitchen staff and hospitality
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=5) as (POS:ADP,DEP:prep,TAG:IN,Position=12) kitchen (POS:NOUN,DEP:compound,TAG:NN,Position=15) staff (POS:NOUN,DEP:pobj,TAG:NN,Position=23) and (POS:CCONJ,DEP:cc,TAG:CC,Position=29) hospitality (POS:NOUN,DEP:conj,TAG:NN,Position=33)
# Root: staff
# Phrase: kitchen staff
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=5) as (POS:ADP,DEP:prep,TAG:IN,Position=12) hospitality (POS:NOUN,DEP:conj,TAG:NN,Position=33)
# Root: hospitality
# Phrase: hospitality

# %% [markdown]
# ## Initial Issues
#
# ~~In sentence 2, note that 'was president African - American' is not very descriptive. It should note that he was the **first** african-american president.~~
#
# ~~**Resolution**: capture the subtree of each traversed token~~
#
# Honestly it doesn't matter, it should just note that he was African-American and that is the only relationship that matters for this sentence semantically. If the link was 'African-American president', then maybe it should be different.
#
# In sentence 3, note that 'representing from as an Illinois state senator from 1997 to 2004' is not accurate. It should really just say 'representing as an Illinois state senator from 1997 to 2004'. It's capturing the 'from' from the first conjuction.
#
# **Resolution**: handle conjunctions better so that -
# 1. If conjunction is the ancestor, skip the conjunction and go to the next ancestor until verb is found.

# %% [markdown]
# ## Longer Samples

# %%
article = [
    Extract(
        text="Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.",
        links=["president of the United States"]
    ),
    Extract(
        text="A member of the Democratic Party, he was the first African-American president in U.S. history.",
        links=["African-American", "Democratic Party"]
    ),
    Extract(
        text="Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.",
        links=["U.S. senator", "Illinois", "Illinois state senator"]
    ),
    Extract(
        text="Obama was born in Honolulu, Hawaii.",
        links=["Honolulu"]
    ),
    Extract(
        text="He graduated from Columbia University in 1983 with a Bachelor of Arts degree in political science and later worked as a community organizer in Chicago.",
        links=["Columbia University", "Bachelor of Arts", "community organizer", "Chicago"]
    ),
    Extract(
        text="In 1988, Obama enrolled in Harvard Law School, where he was the first black president of the Harvard Law Review.",
        links=["Harvard Law School", "Harvard Law Review"]
    ),
    Extract(
        text="He became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004.",
        links=["constitutional law", "University of Chicago Law School"]
    ),
    Extract(
        text="In 1996, Obama was elected to represent the 13th district in the Illinois Senate, a position he held until 2004, when he successfully ran for the U.S. Senate.",
        links=["represent the 13th district in the Illinois Senate", "successfully ran for the U.S. Senate"]
    ),
    Extract(
        text="In the 2008 presidential election, after a close primary campaign against Hillary Clinton, he was nominated by the Democratic Party for president.",
        links=["2008 presidential election", "close primary campaign", "Hillary Clinton"]
    ),
    Extract(
        text="Obama selected Joe Biden as his running mate and defeated Republican nominee John McCain.",
        links=["Joe Biden", "John McCain"]
    )
]

# %%
render_multi_phrase_relationship(article)
# Out:
# Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.
# served (POS:VERB,DEP:relcl,TAG:VBD,Position=87) as the 44th president of the United States
# Root: president
# Phrase: president of the United States
#
# A member of the Democratic Party, he was the first African-American president in U.S. history.
# was (POS:AUX,DEP:ROOT,TAG:VBD,Position=37) president African - American
# Root: American
# Phrase: African-American
# was (POS:AUX,DEP:ROOT,TAG:VBD,Position=37) member of the Democratic Party
# Root: Party
# Phrase: Democratic Party
#
# Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=17) as a U.S. senator representing (POS:VERB,DEP:acl,TAG:VBG,Position=42) Illinois from 2005 to 2008
# Root: senator
# Phrase: U.S. senator
# representing (POS:VERB,DEP:acl,TAG:VBG,Position=42) Illinois
# Root: Illinois
# Phrase: Illinois
# served (POS:VERB,DEP:ROOT,TAG:VBD,Position=17) as an Illinois state senator from 1997 to 2004
# Root: senator
# Phrase: Illinois state senator
#
# Obama was born in Honolulu, Hawaii.
# born (POS:VERB,DEP:ROOT,TAG:VBN,Position=10) in Honolulu , Hawaii
# Root: Honolulu
# Phrase: Honolulu
#
# He graduated from Columbia University in 1983 with a Bachelor of Arts degree in political science and later worked as a community organizer in Chicago.
# graduated (POS:VERB,DEP:ROOT,TAG:VBD,Position=3) from Columbia University
# Root: University
# Phrase: Columbia University
# graduated (POS:VERB,DEP:ROOT,TAG:VBD,Position=3) with degree Bachelor of Arts
# Root: Bachelor
# Phrase: Bachelor of Arts
# worked (POS:VERB,DEP:conj,TAG:VBD,Position=108) as a community organizer in Chicago
# Root: organizer
# Phrase: community organizer
# worked (POS:VERB,DEP:conj,TAG:VBD,Position=108) as organizer in Chicago
# Root: Chicago
# Phrase: Chicago
#
# In 1988, Obama enrolled in Harvard Law School, where he was the first black president of the Harvard Law Review.
# enrolled (POS:VERB,DEP:ROOT,TAG:VBD,Position=15) in Harvard Law School , where he was (POS:AUX,DEP:relcl,TAG:VBD,Position=56) the first black president of the Harvard Law Review
# Root: School
# Phrase: Harvard Law School
# was (POS:AUX,DEP:relcl,TAG:VBD,Position=56) president of the Harvard Law Review
# Root: Review
# Phrase: Harvard Law Review
#
# He became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004.
# teaching (POS:VERB,DEP:advcl,TAG:VBG,Position=51) constitutional law
# Root: law
# Phrase: constitutional law
# teaching (POS:VERB,DEP:advcl,TAG:VBG,Position=51) at the University of Chicago Law School from 1992
# Root: University
# Phrase: University of Chicago Law School
#
# In 1996, Obama was elected to represent the 13th district in the Illinois Senate, a position he held until 2004, when he successfully ran for the U.S. Senate.
# to represent (POS:VERB,DEP:xcomp,TAG:VB,Position=30) the 13th district in the Illinois Senate , a position he held (POS:VERB,DEP:relcl,TAG:VBD,Position=96) until 2004 , when he successfully ran (POS:VERB,DEP:relcl,TAG:VBD,Position=134) for the U.S. Senate
# Root: represent
# Phrase: represent the 13th district in the Illinois Senate
# when he successfully ran (POS:VERB,DEP:relcl,TAG:VBD,Position=134) for the U.S. Senate
# Root: ran
# Phrase: successfully ran for the U.S. Senate
#
# In the 2008 presidential election, after a close primary campaign against Hillary Clinton, he was nominated by the Democratic Party for president.
# nominated (POS:VERB,DEP:ROOT,TAG:VBN,Position=98) In the 2008 presidential election
# Root: election
# Phrase: 2008 presidential election
# nominated (POS:VERB,DEP:ROOT,TAG:VBN,Position=98) after a close primary campaign against Hillary Clinton
# Root: campaign
# Phrase: close primary campaign
# nominated (POS:VERB,DEP:ROOT,TAG:VBN,Position=98) after campaign against Hillary Clinton
# Root: Clinton
# Phrase: Hillary Clinton
#
# Obama selected Joe Biden as his running mate and defeated Republican nominee John McCain.
# selected (POS:VERB,DEP:ROOT,TAG:VBD,Position=6) Joe Biden
# Root: Biden
# Phrase: Joe Biden
# defeated (POS:VERB,DEP:conj,TAG:VBN,Position=49) Republican nominee John McCain
# Root: McCain
# Phrase: John McCain

# %% [markdown]
# In sentence 3, we can probably find a better verb matching for U.S. senator, Illinois, and Illinois state senator. Because yes, he did represent Illinois, but he did not represent an Illinois state senator, and he did not represent a U.S. senator. This is because I had added code that will just grab the phrase subtree if a verb is found in it.

# %% [markdown]
# ## Relationship Finding State Machine
#
# For a relationship we want to have 3 main fields:
# ```python
# class Relationship:
#     verb_action: str
#     detailed_action: str
#     outgoing: str
# ```
# where `outgoing` will be the phrase we are searching for. `verb_action` is the single verb that represents the action. `detailed_action` includes details that qualify the verb and the `outgoing` link. We will assume that the main entity is the article title.

# %% [markdown]
# ### State Machine
#
# | state (including root) | is_conj | add_token? | next_state   |
# |------------------------|---------|------------|--------------|
# | pos=verb               | false   | yes        | break        |
# | pos=verb               | true    | yes        | break        |
# | pos=aux                | false   | yes        | break        |
# | pos=aux                | true    | yes        | break        |
# | dep=conj               | false   | yes        | is_conj=true |
# | dep=conj               | true    | no         | is_conj=true |
# | _                      | false   | yes        | next         |
# | _                      | true    | no         | is_conj=false|

# %% [markdown]
# **Special consideration for the root (the first token)**:
# * if the root is a verb or aux, then the subtree of the root should just be returned.
# * is_conj is set to whether the root is a conjugated clause (dep_ == "conj").
# * the root will always be added.

# %% [markdown]
# ### Code

# %%
class Relationship:
    def __init__(self, action: str, detailed_action: str, target: str):
        self.action = action
        self.detailed_action = detailed_action
        self.target = target

def evaluate_relationships(span: Span):
    tokens = list(span.subtree)
    if span.root.pos_ == "VERB" or span.root.pos_ == "AUX":
        return Relationship(action=span.root.text, detailed_action=convert_tokens_to_text(tokens), target=span.text)
    is_conj = span.root.dep_ == "conj"
    for token in span.root.ancestors:
        if token.pos_ == "VERB" or token.pos_ == "AUX":
            tokens.insert(0, token)
            return Relationship(action=token.text, detailed_action=convert_tokens_to_text(tokens), target=span.text)
        elif not is_conj:
            tokens.insert(0, token)
        elif is_conj:
            is_conj = False

        if token.dep_  == "conj":
            is_conj = True
    return None

def convert_tokens_to_text(tokens: Iterator[Token]):
    return " ".join(token.text.strip() for token in tokens)

# %%
span = get_phrase_span(nlp(article[0].text), "president of the United States")
relationship = evaluate_relationships(span)
f"action={relationship.action},detailed_action={relationship.detailed_action},outgoing={relationship.target}"
# Out:
# 'action=served,detailed_action=served as the 44th president of the United States,outgoing=president of the United States'

# %% [markdown]
# ## Code V2

# %% [markdown]
# Evaluating relationships:

# %%
class Relationship:
    def __init__(self, action: str, detailed_action: str, target: str):
        self.action = action
        self.detailed_action = detailed_action
        self.target = target

def evaluate_relationships(span: Span):
    tokens = list(span.subtree)
    if span.root.pos_ == "VERB" or span.root.pos_ == "AUX":
        return Relationship(action=span.root.text, detailed_action=convert_tokens_to_text(tokens), target=span.text)
    is_conj = span.root.dep_ == "conj"
    for token in span.root.ancestors:
        if token.pos_ == "VERB" or token.pos_ == "AUX":
            tokens.insert(0, token)
            return Relationship(action=token.text, detailed_action=convert_tokens_to_text(tokens), target=span.text)
        elif not is_conj:
            tokens.insert(0, token)
        elif is_conj:
            is_conj = False

        if token.dep_  == "conj":
            is_conj = True
    return None

def convert_tokens_to_text(tokens: Iterator[Token]):
    return " ".join(token.text.strip() for token in tokens)

# %% [markdown]
# Rendering relationships for debugging:

# %%
def render_relationship(relationship: Relationship):
    print(f"Detail: {colored(relationship.detailed_action, 'cyan')}")
    print(f"Action: {colored(relationship.action, 'green')}")
    print(f"Target: {colored(relationship.target, 'light_magenta')}")

# %% [markdown]
# For processing strings:

# %%
def process_extracts(extracts: Iterator[Extract]):
    docs = nlp.pipe(ext.text for ext in extracts)
    for (sent, doc) in zip(extracts, docs):
        print()
        print(f"Text: {sent.text}")
        for link in sent.links:
            target_span = get_phrase_span(doc, link)
            relationship = evaluate_relationships(target_span)
            render_relationship(relationship)

# %% [markdown]
# ### Examples

# %%
process_extracts(article)
# Out:
# Text: Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.
# Detail: served as the 44th president of the United States
# Action: served
# Target: president of the United States
#
# Text: A member of the Democratic Party, he was the first African-American president in U.S. history.
# Detail: was president African - American
# Action: was
# Target: African-American
# Detail: was member of the Democratic Party
# Action: was
# Target: Democratic Party
#
# Text: Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.
# Detail: served as a U.S. senator representing Illinois from 2005 to 2008
# Action: served
# Target: U.S. senator
# Detail: representing Illinois
# Action: representing
# Target: Illinois
# Detail: served as an Illinois state senator from 1997 to 2004
# Action: served
# Target: Illinois state senator
#
# Text: Obama was born in Honolulu, Hawaii.
# Detail: born in Honolulu , Hawaii
# Action: born
# Target: Honolulu
#
# Text: He graduated from Columbia University in 1983 with a Bachelor of Arts degree in political science and later worked as a community organizer in Chicago.
# Detail: graduated from Columbia University
# Action: graduated
# Target: Columbia University
# Detail: graduated with degree Bachelor of Arts
# Action: graduated
# Target: Bachelor of Arts
# Detail: worked as a community organizer in Chicago
# Action: worked
# Target: community organizer
# Detail: worked as organizer in Chicago
# Action: worked
# Target: Chicago
#
# Text: In 1988, Obama enrolled in Harvard Law School, where he was the first black president of the Harvard Law Review.
# Detail: enrolled in Harvard Law School , where he was the first black president of the Harvard Law Review
# Action: enrolled
# Target: Harvard Law School
# Detail: was president of the Harvard Law Review
# Action: was
# Target: Harvard Law Review
#
# Text: He became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004.
# Detail: teaching constitutional law
# Action: teaching
# Target: constitutional law
# Detail: teaching at the University of Chicago Law School from 1992
# Action: teaching
# Target: University of Chicago Law School
#
# Text: In 1996, Obama was elected to represent the 13th district in the Illinois Senate, a position he held until 2004, when he successfully ran for the U.S. Senate.
# Detail: to represent the 13th district in the Illinois Senate , a position he held until 2004 , when he successfully ran for the U.S. Senate
# Action: represent
# Target: represent the 13th district in the Illinois Senate
# Detail: when he successfully ran for the U.S. Senate
# Action: ran
# Target: successfully ran for the U.S. Senate
#
# Text: In the 2008 presidential election, after a close primary campaign against Hillary Clinton, he was nominated by the Democratic Party for president.
# Detail: nominated In the 2008 presidential election
# Action: nominated
# Target: 2008 presidential election
# Detail: nominated after a close primary campaign against Hillary Clinton
# Action: nominated
# Target: close primary campaign
# Detail: nominated after campaign against Hillary Clinton
# Action: nominated
# Target: Hillary Clinton
#
# Text: Obama selected Joe Biden as his running mate and defeated Republican nominee John McCain.
# Detail: selected Joe Biden
# Action: selected
# Target: Joe Biden
# Detail: defeated Republican nominee John McCain
# Action: defeated
# Target: John McCain

# %% [markdown]
# ## Further Optimizations
#
# One optimization we can do is add additional qualifiers to the verb. For example, for many of these sentences above, there are prepositions connecting the verb to the target word. (e.g. 'teaching' and 'University of Chicago Law School' are connected by 'at'). This detail is shown in the detailed action, but we should more concretely identify what the preposition is in a separate field.
#
# Generally, the POS `ADP` should work well in this case. We don't want to use "prep" dependency because it doesn't always work, for example it may be part of a conj clause, in which case `dep_ == "conj"`

# %%
class Relationship:
    def __init__(self, action: str, prep: str, detailed_action: str, target: str):
        self.action = action
        self.prep = prep
        self.detailed_action = detailed_action
        self.target = target

def evaluate_relationships(span: Span):
    tokens = list(span.subtree)
    if span.root.pos_ == "VERB" or span.root.pos_ == "AUX":
        return Relationship(action=span.root.text, prep=None, detailed_action=convert_tokens_to_text(tokens), target=span.text)
    is_conj = span.root.dep_ == "conj"
    prep = span.root if span.root.pos_ == "ADP" else None
    for token in span.root.ancestors:
        if token.pos_ == "VERB" or token.pos_ == "AUX":
            tokens.insert(0, token)
            return Relationship(action=token.text, prep=prep, detailed_action=convert_tokens_to_text(tokens), target=span.text)
        elif is_conj:
            is_conj = False
        elif not is_conj:
            tokens.insert(0, token)
        
        if token.pos_ == "ADP" and prep == None:
            prep = token.text
        if token.dep_ == "conj":
            is_conj = True
    return None

# %%
def render_relationship(relationship: Relationship):
    print(f"Detail: {colored(relationship.detailed_action, 'cyan')}")
    print(f"Action: {colored(relationship.action, 'green')}")
    print(f"Prep: {colored(relationship.prep, 'green')}")
    print(f"Target: {colored(relationship.target, 'light_magenta')}")

# %%
process_extracts(article)
# Out:
# Text: Barack Hussein Obama II (born August 4, 1961) is an American lawyer and politician who served as the 44th president of the United States from 2009 to 2017.
# Detail: served as the 44th president of the United States
# Action: served
# Prep: as
# Target: president of the United States
#
# Text: A member of the Democratic Party, he was the first African-American president in U.S. history.
# Detail: was president African - American
# Action: was
# Prep: None
# Target: African-American
# Detail: was member of the Democratic Party
# Action: was
# Prep: of
# Target: Democratic Party
#
# Text: Obama previously served as a U.S. senator representing Illinois from 2005 to 2008, and as an Illinois state senator from 1997 to 2004.
# Detail: served as a U.S. senator representing Illinois from 2005 to 2008
# Action: served
# Prep: as
# Target: U.S. senator
# Detail: representing Illinois
# Action: representing
# Prep: None
# Target: Illinois
# Detail: served as an Illinois state senator from 1997 to 2004
# Action: served
# Prep: as
# Target: Illinois state senator
#
# Text: Obama was born in Honolulu, Hawaii.
# Detail: born in Honolulu , Hawaii
# Action: born
# Prep: in
# Target: Honolulu
#
# Text: He graduated from Columbia University in 1983 with a Bachelor of Arts degree in political science and later worked as a community organizer in Chicago.
# Detail: graduated from Columbia University
# Action: graduated
# Prep: from
# Target: Columbia University
# Detail: graduated with degree Bachelor of Arts
# Action: graduated
# Prep: with
# Target: Bachelor of Arts
# Detail: worked as a community organizer in Chicago
# Action: worked
# Prep: as
# Target: community organizer
# Detail: worked as organizer in Chicago
# Action: worked
# Prep: in
# Target: Chicago
#
# Text: In 1988, Obama enrolled in Harvard Law School, where he was the first black president of the Harvard Law Review.
# Detail: enrolled in Harvard Law School , where he was the first black president of the Harvard Law Review
# Action: enrolled
# Prep: in
# Target: Harvard Law School
# Detail: was president of the Harvard Law Review
# Action: was
# Prep: of
# Target: Harvard Law Review
#
# Text: He became a civil rights attorney and an academic, teaching constitutional law at the University of Chicago Law School from 1992 to 2004.
# Detail: teaching constitutional law
# Action: teaching
# Prep: None
# Target: constitutional law
# Detail: teaching at the University of Chicago Law School from 1992
# Action: teaching
# Prep: at
# Target: University of Chicago Law School
#
# Text: In 1996, Obama was elected to represent the 13th district in the Illinois Senate, a position he held until 2004, when he successfully ran for the U.S. Senate.
# Detail: to represent the 13th district in the Illinois Senate , a position he held until 2004 , when he successfully ran for the U.S. Senate
# Action: represent
# Prep: None
# Target: represent the 13th district in the Illinois Senate
# Detail: when he successfully ran for the U.S. Senate
# Action: ran
# Prep: None
# Target: successfully ran for the U.S. Senate
#
# Text: In the 2008 presidential election, after a close primary campaign against Hillary Clinton, he was nominated by the Democratic Party for president.
# Detail: nominated In the 2008 presidential election
# Action: nominated
# Prep: In
# Target: 2008 presidential election
# Detail: nominated after a close primary campaign against Hillary Clinton
# Action: nominated
# Prep: after
# Target: close primary campaign
# Detail: nominated after campaign against Hillary Clinton
# Action: nominated
# Prep: against
# Target: Hillary Clinton
#
# Text: Obama selected Joe Biden as his running mate and defeated Republican nominee John McCain.
# Detail: selected Joe Biden
# Action: selected
# Prep: None
# Target: Joe Biden
# Detail: defeated Republican nominee John McCain
# Action: defeated
# Prep: None
# Target: John McCain

# %% [markdown]
# ## Final State Machine
#
# | state (including root) | is_conj | add_token? | next_state   | set prep token? |
# |------------------------|---------|------------|--------------|-----------------|
# | pos=verb               | false   | yes        | break        | no              |
# | pos=verb               | true    | yes        | break        | no              |
# | pos=aux                | false   | yes        | break        | no              |
# | pos=aux                | true    | yes        | break        | no              |
# | dep=conj               | false   | yes        | is_conj=true | no              |
# | dep=conj               | true    | no         | is_conj=true | no              |
# | pos=adp                | false   | yes        | next         | yes             |
# | pos=adp                | true    | no         | is_conj=false| yes             |
# | _                      | false   | yes        | next         | no              |
# | _                      | true    | no         | is_conj=false| no              |
